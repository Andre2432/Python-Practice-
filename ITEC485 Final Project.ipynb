# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #alias
from pandas_datareader import data

coronaData = pd.read_csv("c:/shared code/485project.csv") #don't use a backslash, python thinks its end of line



coronaData
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
#     Date Collected  CDC Labs  US Public Health Labs  Total Tests Given  \
# 0           18-Jan         4                      0                  4
# 1           19-Jan         0                      0                  0
# 2           20-Jan         7                      0                  7
# 3           21-Jan         3                      0                  3
# 4           22-Jan        10                      0                 10
# ..             ...       ...                    ...                ...
# 96          23-Apr        31                  17687              17718
# 97          24-Apr        19                  14984              15003
# 98          25-Apr        18                   3359               3377
# ...

# %%
#testing
#coronaTesting = np.log(coronaData['Total Tests Given'])
fiveDayTest = coronaData['Total Tests Given'].rolling(window=5).mean() #20 day moving window, using average method
sevenDayTest = coronaData['Total Tests Given'].rolling(window=7).mean() #100 day moving window, using average method
tenDayTest = coronaData['Total Tests Given'].rolling(window=10).mean() #100 day moving window, using average method
thirtyDayTest = coronaData['Total Tests Given'].rolling(window=30).mean() #100 day moving window, using average method
#confirmed
fiveDayConfirmed = coronaData['Daily Confirmed Cases'].rolling(window=5).mean() #20 day moving window, using average method
sevenDayConfirmed = coronaData['Daily Confirmed Cases'].rolling(window=7).mean() #100 day moving window, using average method
tenDayConfirmed = coronaData['Daily Confirmed Cases'].rolling(window=10).mean() #100 day moving window, using average method
thirtyDayConfirmed = coronaData['Daily Confirmed Cases'].rolling(window=30).mean() #100 day moving window, using average method



fig, ax = plt.subplots(figsize=(16,9))
#ax.plot(coronaData['Total Tests Given'], label='Tests')
ax.plot(sevenDayTest, label='7 day Testing')
ax.plot(sevenDayConfirmed, label='7 day Confirmed')
#ax.plot(thirtyDayWindow, label='Ten Day Window')


ax.legend()
